# %% [markdown]
# # For git practice

# %%
print('Hello world')
# Out:
# Hello world

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
wan = np.random.normal(0,1,10_000)
wan
# Out:
# array([ 0.52938753, -0.43649898,  0.39343665, ..., -0.45204527,
#        -0.61168645,  0.78741903])

# %%
plt.plot(wan, 'bo')
